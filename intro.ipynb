# %%
# %pip install -U -q gtbook
# Out:
# WARNING: Skipping /usr/local/lib/python3.12/site-packages/pygments-2.17.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.12/site-packages/TBB-0.2.dist-info due to invalid metadata entry 'name'
# DEPRECATION: Loading egg at /usr/local/Cellar/gpgme/1.23.2/lib/python3.12/site-packages/gpg-1.23.2-py3.12-macosx-14-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Skipping /usr/local/lib/python3.12/site-packages/pygments-2.17.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.12/site-packages/TBB-0.2.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /usr/local/Cellar/jupyterlab/4.0.9_2/libexec/bin/python -m pip install --upgrade pip
# ...

# %% [markdown]
# # Introduction to Robotics and Perception

# %% [markdown]
# This is an introductory robotics text, entirely written in executable notebooks, first developed for use in CS3630 "Introduction to Robotics and Perception" at Georgia Tech.
# Please note everything here is considered preliminary and subject to mistakes, typos, broken code etc. Feel free to use the issue tracker (click on github icon above) to alert us of any mistakes.

# %% [markdown]
# 这是一本面向初学者的机器人学教程，全部内容以jupyter book交互式编程笔记本的形式呈现，最初是为乔治亚理工学院的CS3630《机器人学和感知导论》课程而设计。
# 请注意，这里的所有内容都是初稿版本，可能包含一些错误、打字疏漏或编程Bug等问题。如果您发现了任何问题，请随时通过点击上方的GitHub图标，使用问题跟踪器（issue）向我们反馈。

# %% [markdown]
# <img src="Figures0/S51-Two-wheeled_Toy_Robot-01.jpg" alt="Splash image with 3 robots" width="90%" align=center style="vertical-align:middle;margin:10px 0px">

# %% [markdown]
# About the art: all images were generated by Frank Dellaert based on the chapter and section topics, initially using [OpenAI's Glide code](https://github.com/openai/glide-text2im), and later using [Dalle-2](https://openai.com/product/dall-e-2).

# %% [markdown]
# 艺术创作：该教程内的所有图像都是由Frank Dellaert依据教材的各章节和小节主题绘制而成，起初是利用OpenAI的Glide代码进行生成，后期则转为使用了Dalle-2。

# %% [markdown]
# Acknowledgements: We would like to acknowledge all the TAs and students in 3630 in Spring 2022 and beyond for their help in flagging errors/typos and helping to create assignments for the course.
